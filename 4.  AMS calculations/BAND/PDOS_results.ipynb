# %% [markdown]
# The following image shows the DOS for the Vanadium defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Chromium defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Niobium defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Molybdenum defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Tantalum defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Tungsten defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The following image shows the DOS for the Rhenium defect:
#
# ![image.png](attachment:image.png)
