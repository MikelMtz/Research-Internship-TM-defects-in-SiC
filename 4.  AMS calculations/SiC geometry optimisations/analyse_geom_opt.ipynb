# %% [markdown]
# # Volume functions

# %%
import numpy as np

limit=10

def volume_values(a,b,c,alpha, beta, gamma):
    G = np.linalg.det(np.array([[a**2,a*b*np.cos(gamma),a*c*np.cos(beta)],[a*b*np.cos(gamma),b**2,b*c*np.cos(alpha)],[a*c*np.cos(beta),b*c*np.cos(alpha),c**2]]))
    return np.sqrt(G)

def volume_vectors(a1,a2,a3):
    b=[]
    for i in np.cross(a2,a3): b.append(i)
    return abs(np.dot(a1, b))

# 90 --> pi/2
# 120 --> pi*2/3

# %% [markdown]
# # Complete analysis

# %%
import matplotlib.pyplot as plt

non_deformed_bulk_3 = volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))
V_3 = volume_vectors((4.71864273882524,      -8.24046887922553,      -0.01479894404203),(4.71885814066661,       8.24059324153663,       0.01567684312146),(0.00287027393824,       0.05752717646125,      31.17463755588560))
Cr_3 = volume_vectors((4.71718443169159,      -8.23937545519098,      -0.01545203171004),(4.71736817141310,       8.23948153736865,       0.01637932446213),(0.00303176558881,       0.06008599658785,      31.16959504417889))
Nb_3 = volume_vectors((4.72176908860117,      -8.24842920307520,      -0.01406303427190),(4.72221689892960,       8.24868774648887,       0.01446063559515),(0.00129994978088,       0.05384229063426,      31.19776673546621))
Mo_3 = volume_vectors((4.72100407019028,      -8.24622086315034,      -0.01365792191382),(4.72158859112736,       8.24655833647070,       0.01424022932403),(0.00190384273403,       0.05266153949011,      31.18405888351912))
Ta_3 = volume_vectors((4.72174402772096,      -8.24877275579089,      -0.01376810016945),(4.72252781726873,       8.24922527689728,       0.01458681882989),(0.00267678471124,       0.05352375051280,      31.19855145704240))
W_3 = volume_vectors((4.72130488246335,      -8.24727082462325,      -0.01324049432111),(4.72212117313688,       8.24774211026335,       0.01403657738775),(0.00260277807826,       0.05148916774893,      31.18643852634497))
Re_3 = volume_vectors((4.72196734264462,      -8.24487581619092,      -0.01571759056504),(4.72213198816700,       8.24497087432759,       0.01662182611039),(0.00295638050053,       0.06104502960862,      31.18729809191546))

volumes = [non_deformed_bulk_3, V_3, Cr_3, Nb_3, Mo_3, Ta_3, W_3, Re_3]
elements = ["non def.", "V", "Cr", "Nb", "Mo", "Ta", "W", "Re"]
plt.scatter(elements, volumes)
plt.title("3x3x3 supercell optimisations of 4H-SiC (defects with one electron)")
plt.xlabel("Defect elements in the configuration")
plt.ylabel("Supercell Volume (Armstrong ^ 3)")
for i,j in zip(volumes, elements):
    plt.annotate(f"{round((i/non_deformed_bulk_3-1)*100, 3)} %", (j, i) )
plt.ylim(2415, 2440)
plt.show()

non_deformed_bulk_5 = volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))
V_5 = volume_vectors((7.88475827684354,     -13.65680194089224,      -0.00000000000000),(7.88475827684354,      13.65680194089224,      -0.00000000000000),(-0.00000000000000,      -0.00000000000000,      20.86590228758918))
Cr_5 = volume_vectors((7.88397241322247,     -13.65544078517274,       0.00000000000000),(7.88397241322248,      13.65544078517274,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.86502501679056))
Nb_5 = volume_vectors((7.88815048078527,     -13.66267741046896,       0.00000000000000),(7.88815048078527,      13.66267741046896,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.87376835397257))
Mo_5 = volume_vectors((7.88736662303496,     -13.66131972901952,       0.00000000000000),(7.88736662303497,      13.66131972901952,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.86924441940437))
Ta_5 = volume_vectors((7.88820443898502,     -13.66277086881241,       0.00000000000000),(7.88820443898503,      13.66277086881241,      -0.00000000000000),(-0.00000000000000,      -0.00000000000000,      20.87368376107690))
W_5 = volume_vectors((7.88758767794031,     -13.66170260734685,      -0.00000000000000),(7.88758767794032,      13.66170260734685 ,     -0.00000000000000),(-0.00000000000000,       0.00000000000000,      20.86865138586899))
Re_5 = volume_vectors((7.88743402514569,     -13.66143647289984,       0.00000000000000),(7.88743402514570,      13.66143647289984 ,     -0.00000000000000),(-0.00000000000000,      -0.00000000000000,      20.86918609958069))

volumes = [non_deformed_bulk_5, V_5, Cr_5, Nb_5, Mo_5, Ta_5, W_5, Re_5]
elements = ["non def.", "V", "Cr", "Nb", "Mo", "Ta", "W", "Re"]
plt.scatter(elements, volumes)
plt.title("5x5x2 supercell optimisations of 4H-SiC (defects with one electron)")
plt.xlabel("Defect elements in the configuration")
plt.ylabel("Supercell Volume (Armstrong ^ 3)")
for i,j in zip(volumes, elements):
    plt.annotate(f"{round((i/non_deformed_bulk_5-1)*100, 3)} %", (j, i) )
plt.ylim(4480, 4510)
plt.show()

# %%
import matplotlib.pyplot as plt

non_deformed_bulk_3 = volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))
V_3 = volume_vectors((4.71366364050782,     -8.23062979329568,      -0.01576502781616),(4.71376543912101,       8.23068856675241,       0.01666064500109),(0.00292820293905,       0.06120784976040,      31.07739282309458))
Cr_3 = volume_vectors((4.71282462056649,      -8.22818701448754,      -0.01591941704174),(4.71295496766868,       8.22826227042208,       0.01681538150318),(0.00292933835283,       0.06179136644494,      31.07262702297995))
Nb_3 = volume_vectors((4.71725629893772,      -8.23826496258924,      -0.01544479284429),(4.71710403548131,       8.23817705324169,       0.01631352532279),(0.00284030391510,       0.05994812745964,      31.10102858322938))
Mo_3 = volume_vectors((4.71605113017322,      -8.23557335134906,      -0.01580546479223),(4.71612587326084,       8.23561650429082,       0.01670466551741),(0.00293991925408,       0.06136727471774,      31.09706950515951))
Ta_3 = volume_vectors((4.71786658166480,      -8.23953517618685,      -0.01565199880089),(4.71713254385773,       8.23911137926134,       0.01603196217689),(0.00124228285595,       0.05980776819257,      31.10135286431877))
W_3 = volume_vectors((4.71718161020310,      -8.23633210381334,      -0.01585639044163),(4.71727567112983,       8.23638640991471,       0.01677653126836),(0.00300838250820,       0.06159906011897,      31.09981645840705))
Re_3 = volume_vectors((4.71658285685191,      -8.23489113572594,      -0.01549645377593),(4.71667934961629,       8.23494684584944,       0.01638019886468),(0.00288938735184,       0.06017149980779,      31.09909845134840))

volumes = [non_deformed_bulk_3, V_3, Cr_3, Nb_3, Mo_3, Ta_3, W_3, Re_3]
elements = ["non def.", "V", "Cr", "Nb", "Mo", "Ta", "W", "Re"]
plt.scatter(elements, volumes)
plt.title("3x3x3 supercell optimisations of 4H-SiC (defects with natural charges)")
plt.xlabel("Defect elements in the configuration")
plt.ylabel("Supercell Volume (Armstrong ^ 3)")
for i,j in zip(volumes, elements):
    plt.annotate(f"{round((i/non_deformed_bulk_3-1)*100, 3)} %", (j, i) )
plt.ylim(2400, 2430)
plt.show()

non_deformed_bulk_5 = volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))
V_5 = volume_vectors((7.87989626982444,     -13.64838069770841,       0.00000000000000),(7.87989626982445,      13.64838069770841,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82396564514562))
Cr_5 = volume_vectors((7.87877801762630,     -13.64644382808555,     -0.00000000000000),(7.87877801762630,      13.64644382808555,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.82331662927489))
Nb_5 = volume_vectors((7.88374935928222,     -13.65505444441539,       0.00000000000000),(7.88374935928223,      13.65505444441539,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83126701513756))
Mo_5 = volume_vectors((7.88278942254492,     -13.65339178521434,       0.00000000000000),(7.88278942254493,      13.65339178521434,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82948883639606))
Ta_5 = volume_vectors((7.88254244328475,     -13.65296400458732,       0.00000000000000),(7.88254244328476,      13.65296400458732,       0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83054228118268))
W_5 = volume_vectors((7.88325255429976,     -13.65419395294432,       0.00000000000000),(7.88325255429977,      13.65419395294432,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83077475200456))
Re_5 = volume_vectors((7.88260545787235,     -13.65307314905464,       0.00000000000000),(7.88260545787235,      13.65307314905464,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.83042714471088))

volumes = [non_deformed_bulk_5, V_5, Cr_5, Nb_5, Mo_5, Ta_5, W_5, Re_5]
elements = ["non def.", "V", "Cr", "Nb", "Mo", "Ta", "W", "Re"]
plt.scatter(elements, volumes)
plt.title("5x5x2 supercell optimisations of 4H-SiC (defects with natural charges)")
plt.xlabel("Defect elements in the configuration")
plt.ylabel("Supercell Volume (Armstrong ^ 3)")
for i,j in zip(volumes, elements):
    plt.annotate(f"{round((i/non_deformed_bulk_5-1)*100, 3)} %", (j, i) )
plt.ylim(4470, 4500)
plt.show()

# %% [markdown]
# # 3x3x3 supercell optimisations of SiC-4H - LibCX PBE

# %% [markdown]
# Vanadium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71366364050782,     -8.23062979329568,      -0.01576502781616),(4.71376543912101,       8.23068856675241,       0.01666064500109),(0.00292820293905,       0.06120784976040,      31.07739282309458))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71366364050782,     -8.23062979329568,      -0.01576502781616),(4.71376543912101,       8.23068856675241,       0.01666064500109),(0.00292820293905,       0.06120784976040,      31.07739282309458))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2411.4084649241595
# #######################################
# The ratio of non-def. to def. volume is: 1.0795567611724657%

# %% [markdown]
# Chromium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71282462056649,      -8.22818701448754,      -0.01591941704174),(4.71295496766868,       8.22826227042208,       0.01681538150318),(0.00292933835283,       0.06179136644494,      31.07262702297995))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71282462056649,      -8.22818701448754,      -0.01591941704174),(4.71295496766868,       8.22826227042208,       0.01681538150318),(0.00292933835283,       0.06179136644494,      31.07262702297995))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2409.9035991030955
# #######################################
# The ratio of non-def. to def. volume is: 1.0788830519708028%

# %% [markdown]
# Niobium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71725629893772,      -8.23826496258924,      -0.01544479284429),(4.71710403548131,       8.23817705324169,       0.01631352532279),(0.00284030391510,       0.05994812745964,      31.10102858322938))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71725629893772,      -8.23826496258924,      -0.01544479284429),(4.71710403548131,       8.23817705324169,       0.01631352532279),(0.00284030391510,       0.05994812745964,      31.10102858322938))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2417.235887697269
# #######################################
# The ratio of non-def. to def. volume is: 1.0821656238958195%

# %% [markdown]
# Molybdenum

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71605113017322,      -8.23557335134906,      -0.01580546479223),(4.71612587326084,       8.23561650429082,       0.01670466551741),(0.00293991925408,       0.06136727471774,      31.09706950515951))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71605113017322,      -8.23557335134906,      -0.01580546479223),(4.71612587326084,       8.23561650429082,       0.01670466551741),(0.00293991925408,       0.06136727471774,      31.09706950515951))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2415.5981503069543
# #######################################
# The ratio of non-def. to def. volume is: 1.0814324297901936%

# %% [markdown]
# Tantalum

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71786658166480,      -8.23953517618685,      -0.01565199880089),(4.71713254385773,       8.23911137926134,       0.01603196217689),(0.00124228285595,       0.05980776819257,      31.10135286431877))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71786658166480,      -8.23953517618685,      -0.01565199880089),(4.71713254385773,       8.23911137926134,       0.01603196217689),(0.00124228285595,       0.05980776819257,      31.10135286431877))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2417.748267141115
# #######################################
# The ratio of non-def. to def. volume is: 1.0823950096265804%

# %% [markdown]
# Tungsten

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71718161020310,      -8.23633210381334,      -0.01585639044163),(4.71727567112983,       8.23638640991471,       0.01677653126836),(0.00300838250820,       0.06159906011897,      31.09981645840705))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71718161020310,      -8.23633210381334,      -0.01585639044163),(4.71727567112983,       8.23638640991471,       0.01677653126836),(0.00300838250820,       0.06159906011897,      31.09981645840705))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2416.6197569457654
# #######################################
# The ratio of non-def. to def. volume is: 1.0818897900301652%

# %% [markdown]
# Rhenium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0),(4.62, 8.002074730968213, 0.0),(0.0, 0.0, 30.21))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.71658285685191,      -8.23489113572594,      -0.01549645377593),(4.71667934961629,       8.23494684584944,       0.01638019886468),(0.00288938735184,       0.06017149980779,      31.09909845134840))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.71658285685191,      -8.23489113572594,      -0.01549645377593),(4.71667934961629,       8.23494684584944,       0.01638019886468),(0.00288938735184,       0.06017149980779,      31.09909845134840))/volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 30.21))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 2233.7023412323592
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 2415.8357656181947
# #######################################
# The ratio of non-def. to def. volume is: 1.0815388071292213%

# %% [markdown]
# # 5x5x2 supercell optimisations of SiC-4H - LibCX PBE

# %% [markdown]
# Vanadium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.87989626982444,     -13.64838069770841,       0.00000000000000),(7.87989626982445,      13.64838069770841,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82396564514562))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.87989626982444,     -13.64838069770841,       0.00000000000000),(7.87989626982445,      13.64838069770841,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82396564514562))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4479.144390578562
# #######################################
# The ratio of non-def. to def. volume is: 1.0828380873603667%

# %% [markdown]
# Chromium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.87877801762630,     -13.64644382808555,     -0.00000000000000),(7.87877801762630,      13.64644382808555,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.82331662927489))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.87877801762630,     -13.64644382808555,     -0.00000000000000),(7.87877801762630,      13.64644382808555,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.82331662927489))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4477.733630828578
# #######################################
# The ratio of non-def. to def. volume is: 1.0824970346377505%

# %% [markdown]
# Niobium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.88374935928222,     -13.65505444441539,       0.00000000000000),(7.88374935928223,      13.65505444441539,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83126701513756))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.88374935928222,     -13.65505444441539,       0.00000000000000),(7.88374935928223,      13.65505444441539,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83126701513756))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4485.097889480909
# #######################################
# The ratio of non-def. to def. volume is: 1.084277352274014%

# %% [markdown]
# Molybdenum

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.88278942254492,     -13.65339178521434,       0.00000000000000),(7.88278942254493,      13.65339178521434,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82948883639606))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.88278942254492,     -13.65339178521434,       0.00000000000000),(7.88278942254493,      13.65339178521434,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.82948883639606))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4483.622972530356
# #######################################
# The ratio of non-def. to def. volume is: 1.0839207894775316%

# %% [markdown]
# Tantalum

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.88254244328475,     -13.65296400458732,       0.00000000000000),(7.88254244328476,      13.65296400458732,       0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83054228118268))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.88254244328475,     -13.65296400458732,       0.00000000000000),(7.88254244328476,      13.65296400458732,       0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83054228118268))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4483.568763670761
# #######################################
# The ratio of non-def. to def. volume is: 1.083907684426048%

# %% [markdown]
# Tungsten

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.88325255429976,     -13.65419395294432,       0.00000000000000),(7.88325255429977,      13.65419395294432,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83077475200456))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.88325255429976,     -13.65419395294432,       0.00000000000000),(7.88325255429977,      13.65419395294432,      -0.00000000000000),(0.00000000000000,      -0.00000000000000,      20.83077475200456))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4484.426664563633
# #######################################
# The ratio of non-def. to def. volume is: 1.0841150829113337%

# %% [markdown]
# Rhenium

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((7.88260545787235,     -13.65307314905464,       0.00000000000000),(7.88260545787235,      13.65307314905464,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.83042714471088))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((7.88260545787235,     -13.65307314905464,       0.00000000000000),(7.88260545787235,      13.65307314905464,       0.00000000000000),(0.00000000000000,       0.00000000000000,      20.83042714471088))/volume_vectors((7.7, -13.33679121828036, 0.0),(7.700000000000006, 13.33679121828036, 0.0),(0.0, 0.0, 20.14))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 4136.485817096966
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 4483.615666624206
# #######################################
# The ratio of non-def. to def. volume is: 1.083919023266677%

# %% [markdown]
# # Old (wrong) optimisations

# %% [markdown]
# ### V defect

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))/volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 744.5674470774532
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 744.5674470774529
# #######################################
# The ratio of non-def. to def. volume is: 1.0000000000000002%

# %% [markdown]
# ### Cr defect

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.00207473096821, 0.0),(4.62, 8.00207473096821, 0.0),(0.0, 0.0, 10.07))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))/volume_vectors((4.62, -8.00207473096821, 0.0),(4.62, 8.00207473096821, 0.0),(0.0, 0.0, 10.07))}%")
# Out:
# The volume of the non-deformed bulk:
# Volume from vectors: 744.5674470774532
# #######################################
# The volume of the deformed bulk:
# Volume from vectors: 744.5674470774529
# #######################################
# The ratio of non-def. to def. volume is: 1.0000000000000002%

# %% [markdown]
# ### Re defect

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))/volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}%")

# %% [markdown]
# ### W defect

# %%
print("The volume of the non-deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print("The volume of the deformed bulk:")
print(f"Volume from vectors: {volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}")
print("#######################################")
print(f"The ratio of non-def. to def. volume is: {volume_vectors((4.62, -8.002074730968213, 0.0), (4.62, 8.002074730968213, 0.0), (0.0, 0.0, 10.07))/volume_vectors((4.62, -8.00207473096821, 0.0), (4.62, 8.00207473096821, 0.0), (0.0, 0.0, 10.07))}%")
