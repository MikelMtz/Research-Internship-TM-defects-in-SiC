# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
x= np.linspace(0, 1, 1000)
ax.plot(0.866025403784439*x,  -0.500000000000000*x ,  0.000000000000000*x)
ax.plot(0.000000000000000*x,   1.000000000000000*x,   0.000000000000000*x)
ax.plot(0.000000000000000*x,   0.000000000000000*x,    4.907211140506062*x)
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
x= np.linspace(0, 1, 1000)
ax.scatter(0.000000000000000,   0.000000000000000,   0.000000000000000, s=25, c='grey',label='Si')
ax.scatter(0.000000000000000,   0.000000000000000,   0.500000000000000, s=25, c='grey')
ax.scatter(0.666666666666667,   0.333333333333333,   0.166666666666667, s=25, c='grey')
ax.scatter(0.333333333333333,   0.666666666666667 ,  0.666666666666667, s=25, c='grey')
ax.scatter(0.333333333333333,   0.666666666666667 ,  0.333333333333333, s=25, c='grey')
ax.scatter(0.666666666666667,   0.333333333333333  , 0.833333333333333, s=25, c='grey')
ax.scatter(0.000000000000000,   0.000000000000000,   0.125270000000000, s=25, c='blue',label='C')
ax.scatter(0.000000000000000,   0.000000000000000,   0.625270000000000, s=25, c='blue')
ax.scatter(0.666666666666667,   0.333333333333333,   0.291880000000000, s=25, c='blue')
ax.scatter(0.333333333333333,   0.666666666666667,   0.791880000000000, s=25, c='blue')
ax.scatter(0.333333333333333,   0.666666666666667,   0.458500000000000, s=25, c='blue')
ax.scatter(0.666666666666667,   0.333333333333333,   0.958500000000000, s=25, c='blue')
plt.legend()
plt.show()

df = pd.read_csv('k_points.csv', delim_whitespace=True)
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection='3d')
for t in range(len(df)):
    x = df['x'][t]
    y = df['y'][t]
    z = df['z'][t]
    ax.scatter(x,y,z, c='red')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
x= np.linspace(0, 1, 1000)
ax.plot(0.866025403784439*x,  -0.500000000000000*x ,  0.000000000000000*x)
ax.plot(0.000000000000000*x,   1.000000000000000*x,   0.000000000000000*x)
ax.plot(0.000000000000000*x,   0.000000000000000*x,    4.907211140506062*x)


x= np.linspace(0, 1, 1000)
ax.scatter(0.000000000000000,   0.000000000000000,   0.000000000000000, s=25, c='grey',label='Si')
ax.scatter(0.000000000000000,   0.000000000000000,   0.500000000000000, s=25, c='grey',label='Si')
ax.scatter(0.666666666666667,   0.333333333333333,   0.166666666666667, s=25, c='grey',label='Si')
ax.scatter(0.333333333333333,   0.666666666666667 ,  0.666666666666667, s=25, c='grey',label='Si')
ax.scatter(0.333333333333333,   0.666666666666667 ,  0.333333333333333, s=25, c='grey',label='Si')
ax.scatter(0.666666666666667,   0.333333333333333  , 0.833333333333333, s=25, c='grey',label='Si')
ax.scatter(0.000000000000000,   0.000000000000000,   0.125270000000000, s=25, c='blue',label='C')
ax.scatter(0.000000000000000,   0.000000000000000,   0.625270000000000, s=25, c='blue',label='C')
ax.scatter(0.666666666666667,   0.333333333333333,   0.291880000000000, s=25, c='blue',label='C')
ax.scatter(0.333333333333333,   0.666666666666667,   0.791880000000000, s=25, c='blue',label='C')
ax.scatter(0.333333333333333,   0.666666666666667,   0.458500000000000, s=25, c='blue',label='C')
ax.scatter(0.666666666666667,   0.333333333333333,   0.958500000000000, s=25, c='blue',label='C')

df = pd.read_csv('k_points.csv', delim_whitespace=True)
for t in range(len(df)):
    x = df['x'][t]
    y = df['y'][t]
    z = df['z'][t]
    ax.scatter(x,y,z, c='red')
plt.legend()
plt.show()
